# %%
import pandas as pd
import tensorflow as tf
import keras as keras
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import tensorflow as tf
#       3 import keras as keras
#       4 import numpy as np
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# If you want to run this file locally, remove the uncommented code in this code block and
# uncomment the commented code.

# df = pd.read_csv('Cleaned_data/combined_df.csv')

# Connecting to my google drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# comment this code block if running locally

df = pd.read_csv('/content/drive/MyDrive/combined_df.csv')

# %%
df.head()
# Out:
#                                             Sentence  Sentiment
# 0  Mid-cap funds can deliver more, stay put: Experts          1
# 1             Mid caps now turn into market darlings          1
# 2          Hudco raises Rs 279 cr via tax-free bonds          1
# 3     EXL beats profit estimates, cuts sales outlook          1
# 4  Would stick to banking: Girish Pai, Centrum Br...          1

# %%
# There are approx. 3500 more positive than negative articles which is a problem

df['Sentiment'].value_counts()
# Out:
# 1    9761
# 0    6201
# Name: Sentiment, dtype: int64

# %%
# removing non-alphanumeric characters since not needed

non_alphanum = [',','.','/','"',':',';','!','@','#','$','%',"'","*","(",")","&","--"]
for char in non_alphanum:
  df['Sentence'] = df['Sentence'].str.replace(char,"")

df['Sentence'] = df['Sentence'].str.replace(" s "," ")
df['Sentence'] = df['Sentence'].str.replace(" '","'")
df['Sentence'] = df['Sentence'].str.replace("  "," ")
df['Sentence'] = df['Sentence'].str.replace("   "," ")
df['Sentence'] = df['Sentence'].str.lower()
# Out:
# <ipython-input-4-20138367653a>:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Sentence'] = df['Sentence'].str.replace(char,"")

# %%
# splitting into training and testing

from sklearn.model_selection import train_test_split

X = df['Sentence'].to_numpy().reshape(-1, 1)
y = df['Sentiment'].to_numpy().reshape(-1, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.1, stratify=y)

# %%
# putting each sentence and sentiment from the training and testing dataframes into lists

training_sentences=[]
testing_sentences=[]
training_labels=[]
testing_labels=[]

for i in X_train:
  training_sentences.append(i[0])
for i in y_train:
  training_labels.append(i[0])
for i in X_test:
  testing_sentences.append(i[0])
for i in y_test:
  testing_labels.append(i[0])

# %%
# importing tokenizer and pad_sequences

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# initialising tokenizer

tokenizer = Tokenizer(num_words=10000, oov_token='####')

# %%
vocab_size = 10000
embedding_dim = 16
max_length = 100
trunc_type='post'
padding_type='post'

# %%
# fitting tokenizer to training sentences
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

# padding
training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

# %%
# word index is a dictionary that indexes each word found in the training sentences

print(word_index)
# Out:
# {'####': 1, 'to': 2, 'the': 3, 'in': 4, 'on': 5, 'of': 6, 'a': 7, 'for': 8, 'and': 9, 'at': 10, 'up': 11, 'is': 12, 'rs': 13, 'from': 14, 'as': 15, 'net': 16, 'it': 17, 'profit': 18, 'aap': 19, 'with': 20, 'over': 21, 'stocks': 22, 'eur': 23, 'will': 24, 'by': 25, 'crore': 26, 'this': 27, 'down': 28, 'be': 29, 'user': 30, 'shares': 31, 'stock': 32, 'its': 33, 'year': 34, 'i': 35, 'short': 36, 'that': 37, 'has': 38, 'after': 39, 'mn': 40, 'today': 41, 'per': 42, 'are': 43, 'company': 44, 'bank': 45, 'market': 46, 'long': 47, 'sales': 48, 'buy': 49, 'new': 50, 'good': 51, 'day': 52, 'high': 53, 'out': 54, 'here': 55, 'more': 56, 'cent': 57, 'not': 58, 'nifty': 59, 'sensex': 60, 'million': 61, 'have': 62, 'like': 63, 'an': 64, 'demand': 65, 'may': 66
': 271, 'rose': 272, 'years': 273, 'upside': 274, '2006': 275, 'their': 276, 'great': 277, 'supply': 278, '100': 279, 'order': 280, '13': 281, 'run': 282, 'our': 283, 'percent': 284, 'second': 285, 'plans': 286, 'daily': 287, 'news': 288, 'space': 289, '52': 290, 'calls': 291, 'holding': 292, 'better': 293, 'sale': 294, 'p': 295, 'think': 296, 'industries': 297, 'how': 298, 'against': 299, 'report': 300, 'another': 301, 'nearly': 302, 'drop': 303, '11': 304, 'open': 305, 'deepak': 306, 'level': ...

# %%
import numpy as np
training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)

# %%
# Out:
# [185, 37, 38, 5214, 10, 3, 285, 8, 7, 6519]

# %%
# building nn

model =  tf.keras.Sequential()
model.add(tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length))
model.add(tf.keras.layers.GlobalAveragePooling1D())
model.add(tf.keras.layers.Dense(10, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_8 (Embedding)     (None, 100, 16)           160000
#
#  global_average_pooling1d_5  (None, 16)                0
#   (GlobalAveragePooling1D)
#
#  dense_19 (Dense)            (None, 10)                170
#
#  dense_20 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 160181 (625.71 KB)
# Trainable params: 160181 (625.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fitting model

num_epochs = 5
history = model.fit(training_padded, training_labels, epochs=num_epochs, validation_data=(testing_padded, testing_labels), verbose=2)
# Out:
# Epoch 1/10
# 449/449 - 3s - loss: 0.6675 - accuracy: 0.6115 - val_loss: 0.6609 - val_accuracy: 0.6118 - 3s/epoch - 6ms/step
# Epoch 2/10
# 449/449 - 2s - loss: 0.6449 - accuracy: 0.6145 - val_loss: 0.6170 - val_accuracy: 0.6374 - 2s/epoch - 4ms/step
# Epoch 3/10
# 449/449 - 2s - loss: 0.5104 - accuracy: 0.7726 - val_loss: 0.4589 - val_accuracy: 0.8065 - 2s/epoch - 4ms/step
# Epoch 4/10
# 449/449 - 2s - loss: 0.3587 - accuracy: 0.8655 - val_loss: 0.4065 - val_accuracy: 0.8165 - 2s/epoch - 4ms/step
# Epoch 5/10
# 449/449 - 3s - loss: 0.2890 - accuracy: 0.8920 - val_loss: 0.3804 - val_accuracy: 0.8322 - 3s/epoch - 6ms/step
# Epoch 6/10
# 449/449 - 2s - loss: 0.2491 - accuracy: 0.9076 - val_loss: 0.3797 - val_accuracy: 0.8397 - 2s/epoch - 4ms/step
# Epoch 7/10
# 449/449 - 2s - loss: 0.2216 - accuracy: 0.9191 - val_loss: 0.3843 - val_accuracy: 0.8428 - 2s/epoch - 4ms/step
# Epoch 8/10
# 449/449 - 2s - loss: 0.2007 - accuracy: 0.9277 - val_loss: 0.3907 - val_accuracy: 0.8403 - 2s/epoch - 4ms/step
# Epoch 9/10
# 449/449 - 2s - loss: 0.1811 - accuracy: 0.9366 - val_loss: 0.3957 - val_accuracy: 0.8403 - 2s/epoch - 4ms/step
# Epoch 10/10
# 449/449 - 2s - loss: 0.1644 - accuracy: 0.9425 - val_loss: 0.4068 - val_accuracy: 0.8416 - 2s/epoch - 3ms/step

# %%
# Trying made up sentences

sentence = ["RBA thinks worst of inflation is not over","telsa stock increases 90%"]
sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(model.predict(padded))
# Out:
# 1/1 [==============================] - 0s 22ms/step
# [[0.0318249]
#  [0.9727442]]

# %%
# Doesn't do well in some cases

sentence = ["tesla stock decreases","energy costs skyrocket"]
sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(model.predict(padded))
# Out:
# 1/1 [==============================] - 0s 104ms/step
# [[0.54026693]
#  [0.67141825]]

# %%
# clearly biased towards 1 (positive)

sentence = [""]
sequences = tokenizer.texts_to_sequences(sentence)
padded = pad_sequences(sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)
print(model.predict(padded))
# Out:
# 1/1 [==============================] - 0s 34ms/step
# [[0.6624477]]
