# %%
import pandas as pd

df = pd.read_csv("news_data.csv")

# Display the first few rows to explore
# df.head(20)

new_df = df[['title', 'url', 'ticker_sentiment', 'overall_sentiment_score', 'overall_sentiment_label']]

new_df.to_csv('new_headlines_data.csv', index=False)

new_df.head(5)
# Out:
#                                                title  \
# 0  Burrow throws 3 TD passes to lead the Bengals ...
# 1  UAW deal with Ford includes $8.1 billion in in...
# 2  KENVUE ONGOING DEADLINE ALERT: Securities Liti...
# 3  Towards a waste-free world; startups develop s...
# 4  Trump's Public Commentary Halted Again By Gag ...
#
#                                                  url  \
# 0  https://apnews.com/article/nfl-bengals-49ers-j...
# 1  https://www.cnbc.com/2023/10/30/uaw-ford-deal-...
# 2  https://www.prnewswire.com/news-releases/kenvu...
# 3  https://www.financialexpress.com/business/indu...
# 4  https://www.benzinga.com/news/23/10/35482723/t...
#
#                                     ticker_sentiment  overall_sentiment_score  \
# 0  [{'ticker': 'DSSMY', 'relevance_score': '0.056...                 0.024097
# 1  [{'ticker': 'F', 'relevance_score': '0.121959'...                 0.169592
# 2  [{'ticker': 'KVUE', 'relevance_score': '0.6001...                 0.150018
# 3  [{'ticker': 'GOOG', 'relevance_score': '0.2287...                 0.241769
# 4  [{'ticker': 'DSSMY', 'relevance_score': '0.103...                -0.150135
#
#   overall_sentiment_label
# 0                 Neutral
# 1        Somewhat-Bullish
# 2        Somewhat-Bullish
# 3        Somewhat-Bullish
# 4        Somewhat-Bearish

# %%
headlines = []

for t in new_df['title']:
    headlines.append(t)

headlines
# Out:
# ['Burrow throws 3 TD passes to lead the Bengals past the 49ers 31-17',
#  'UAW deal with Ford includes $8.1 billion in investments, $5,000 ratification bonuses',
#  'KENVUE ONGOING DEADLINE ALERT: Securities Litigation Partner James (Josh) Wilson Encourages Investors Who ... - PR Newswire',
#  'Towards a waste-free world; startups develop solutions to achieve carbon neutrality',
#  "Trump's Public Commentary Halted Again By Gag Order In Election Case",
#  'UAW Strike Expansion With GM Shows Union Strategy: Surprise and Misdirection',
#  "Trump Says Legal Bills Exceed $100M Amid Multiple Legal Disputes: 'Cost Me A Couple Of Billion Dollars To Be A Politician'",
#  "CGMagazine Launches Last Issue of 2023 with Marvel's Spider-Man 2 - Canada NewsWire",
#  'Taiwan 2024 Lantern Festival in Tainan',
#  'Linq Wins Samsung Open Collaboration with LLM-Enhanced Underwriting AI Solution',
#  'Australia retail sales rise 0.9% in Sept, beat forecasts',
#  "'Doughnuts' loom: Bankers brace for brutal bonus season",
#  'Oil dips as caution about data-heavy week offsets Mid-East war boost',
#  "U.S. Business Group Meets China's Foreign Minister, Lauds Exchanges Ahead Of APEC Meeting",
#  'UK regulator awards 27 oil, gas exploration licenses',
#  'Asia stocks dip on Middle East, central bank meetings',
#  'Hong Kong property moves may lift deal volumes but price stability is key',
#  "A test of American power, how leaders are different to managers and the world's first flying taxi",
#  'Toray Develops TORAYCA™ T1200, the Ultra-High-Strength Carbon Fiber',
#  'EVs create profit potholes for major US automakers GM, Ford',
#  'Governments Meet to Discuss Sustainable Critical Mineral Strategies at Resourcing Tomorrow',
#  'US Treasury seen boosting auction sizes as budget deficit worsens',
#  'BETTING ON THE CONSUMPTION STORY: Higher returns with lesser drawdown',
#  "Police tried to check on the Maine gunman over concerns he could 'snap and commit a mass shooting'",
#  'Judge reinstates gag order on Trump in federal election subversion case | Politics',
#  'Judge reinstates gag order on Trump in federal election subversion case | Politics',
#  'ASP Isotopes Inc. Enters Strategic Relationship With PET Labs Pharmaceuticals for the Distribution of Medical Isotopes',
#  'Xiaomi launches new home-grown OS, as Huawei moves further from Android',
#  "Today's Wordle #863 Hints, Clues And Answer For Monday, October 30th",
#  'High US Bond Yields: Will it impact your portfolio?',
#  'UK risks regulating NFTs the wrong way, says Mintable CEO',
#  'Water Stewardship Will Be One Of The Biggest Food Trends In 2024',
#  "Exclusive: Shangri-La Group's expansion in Middle East to start paying off",
#  'UAW escalates strike against lone holdout GM after landing tentative pacts with Stellantis and Ford',
#  'Qantas blames glitchy system for selling tickets for canceled flights',
#  'HFCL to invest Rs 200 cr for manufacture of 5G FWA device, R&D',
#  'Verstappen Claims Record Victory To Draw Level With Prost',
#  'Qantas files defence against litigation over cancelled flights tickets sale',
#  'Rookie Will Levis throws 4 TDs in his NFL debut as Titans beat Falcons 28-23',
#  "Opinion: Why Matthew Perry was my favorite among 'Friends'",
#  'Oil falls, markets hold steady as Israel launches Gaza ground offensive',
#  "Here's what's new on Netflix in November 2023 -- and what's leaving",
#  "What to know about Iran's role in the fears surrounding a broader Middle East conflict",
#  'US Marine rapid response force moves toward eastern Mediterranean, sources say',
#  'European Aluminum Giant Is Fretting a Chinese EV Influx',
#  'Homebuilders Feel the Squeeze of Tight Housing Market',
#  'Second-largest hospital in Gaza City warned to evacuate ahead of possible bombardment, humanitarian group says',
#  "Climate Change and Regulations Squeeze Alaska's Salmon Fishers",
#  'Israeli airstrikes have caused extensive damage to Gaza hospital, aid organization says',
#  "Could Chase Young and Montez Sweat move with Rivera's Commanders 3-5 after a loss to the Eagles?"]
