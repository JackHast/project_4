# %%
import pandas as pd

df = pd.read_csv("news_data.csv")

# Display the first few rows to explore
# df.head(20)

new_df = df[['title', 'url', 'ticker_sentiment', 'overall_sentiment_score', 'overall_sentiment_label']]

new_df.to_csv('new_headlines_data.csv', index=False)

new_df.head(5)
# Out:
#                                                title  \
# 0  Burning Rock and Boehringer Ingelheim Achieved...
# 1                 LIFT Lists on TSX Venture Exchange
# 2                         'Hubris and mixed signals'
# 3  Elon Musk-Inspired Meme Coin Dogelon Mars Soar...
# 4  Falcon Oil & Gas Ltd. - Beetaloo Operational U...
#
#                                                  url  \
# 0  https://www.globenewswire.com/news-release/202...
# 1  https://www.globenewswire.com/news-release/202...
# 2  https://theweek.com/digest/round-up/hubris-and...
# 3  https://www.benzinga.com/markets/cryptocurrenc...
# 4  https://www.globenewswire.com/news-release/202...
#
#                                     ticker_sentiment  overall_sentiment_score  \
# 0  [{'ticker': 'NHPEF', 'relevance_score': '0.076...                 0.189661
# 1  [{'ticker': 'LIFFF', 'relevance_score': '0.190...                 0.198842
# 2  [{'ticker': 'NYT', 'relevance_score': '0.14873...                -0.074128
# 3  [{'ticker': 'CRYPTO:BTC', 'relevance_score': '...                 0.415015
# 4  [{'ticker': 'FOLGF', 'relevance_score': '0.218...                 0.055595
#
#   overall_sentiment_label
# 0        Somewhat-Bullish
# 1        Somewhat-Bullish
# 2                 Neutral
# 3                 Bullish
# 4                 Neutral

# %%
headlines = []

for t in new_df['title']:
    headlines.append(t)

headlines
# Out:
# ['Burning Rock and Boehringer Ingelheim Achieved a Master Service Agreement in Oncology Companion Diagnostics',
#  'LIFT Lists on TSX Venture Exchange',
#  "'Hubris and mixed signals'",
#  'Elon Musk-Inspired Meme Coin Dogelon Mars Soars 6%, Eclipsing SHIB, DOGE Gains',
#  'Falcon Oil & Gas Ltd. - Beetaloo Operational Update',
#  'Transaction in own shares',
#  'Hexagon Agility receives inaugural order for Mobile Pipeline® TITAN 450 modules from Promigas Peru S.A.',
#  'TERRANET AND ASTAZERO ARE DEVELOPING NEW TESTING METHODS FOR ADVANCED DRIVER ASSISTANCE SYSTEMS',
#  'ICG Enterprise Trust Plc',
#  "China's Wang Yi Says Road To Xi-Biden Summit 'Will Not Be A Smooth One'",
#  'Standard Chartered-owned crypto platform Zodia launches in Hong Kong',
#  "Western Digital Likely To Report Q1 Loss; Here's A Look At Recent Price Target Changes By The Most Accurate Analysts - Western Digital  ( NASDAQ:WDC ) ",
#  "Elon Musk Agrees With Millions Of Users Worldwide, YouTube Ads Are 'Getting Out Of Control' - Alphabet  ( NASDAQ:GOOG ) , Alphabet  ( NASDAQ:GOOGL ) ",
#  "The US and China need to turn down the heat, says California governor Gavin Newsom: 'Divorce is not an option'",
#  'DNO Awarded Operated Blocks in UK Offshore Licensing Round',
#  "Novartis' investigational drug to treat kidney disease demonstrates promising results in Phase III study",
#  "Celine Dion 'civil war' in New Zealand",
#  'Santander readies sale of bad assets worth 5 bln euros- Cinco Dias',
#  'Man City cruise past Man United to win derby and expose gulf in class',
#  'J&T Express makes HKEX debut, a milestone in its journey towards becoming a global logistics leader Middle East ... - PR Newswire',
#  'Artificial Intelligence Market in the Education Sector to Grow by USD 1.10 billion from 2022 to 2027 | 2U Inc., Alphabet ... - PR Newswire',
#  'Oma Savings Bank Plc renews its operating model and initiates change negotiations',
#  'BGHL  ( EUR ) : NAV ( s ) ',
#  'BGHL  ( GBP ) : NAV ( s ) ',
#  'Transaction in Own Shares',
#  'Grupo Simec  ( NYSEAMERICAN:SIM )  Rating Increased to Buy at StockNews.com',
#  "Elon Musk says posts busted by Community Notes won't earn revenue share",
#  'Financials lead slide in Indian shares; Reliance curbs losses',
#  "Instagram will soon let you add photos and videos to your friend's posts",
#  'Tokyo Shares Fall Ahead Of Central Bank Meetings',
#  'Proteomics market to grow by USD 21.74 billion from 2022 to 2027|Agilent Technologies Inc., Applied Biomics Inc., Bio ... - PR Newswire',
#  'Novartis investigational atrasentan Phase III study demonstrates clinically meaningful and highly statistically significant proteinuria reduction in patients with IgA nephropathy  ( IgAN ) ',
#  "HSBC's investment bank slips 10% as trading fees wobble",
#  'Crude oil prices remain uncertain amid geopolitical tensions and weak economic data',
#  "India tribunal allows appeals by Zee's Goenka",
#  'WISeKey SEALSQ Enhances IoT with AI Integration for Advanced Predictive Analysis and Efficient Device Behavior Insights',
#  "Wolters Kluwer to celebrate 50 years of Euronext Amsterdam listing, Nancy McKinstry's 20 years as CEO by sounding ceremonial gong - Wolters Kluwer  ( OTC:WTKWY ) ",
#  'Pfizer Holds MERA Vaccines Summit to Discuss the Impact of Vaccines on Controlling Diseases in the Region',
#  "Wolters Kluwer to celebrate 50 years of Euronext Amsterdam listing, Nancy McKinstry's 20 years as CEO by sounding ceremonial gong",
#  "Dogecoin Co-Creator Billy Markus Calls Bitcoin ATMs A 'RipOff'",
#  'Automotive Tire Market Size to Generate $218.87 Billion By 2030, Growing at a CAGR of 3.8%: Allied Market Research',
#  'GM Strike Grows As UAW Members In Spring Hill Manufacturing Join Picket Lines - Stellantis  ( NYSE:STLA ) , Ford Motor  ( NYSE:F ) , General Motors  ( NYSE:GM ) ',
#  'Drive lah secures strategic investment from ComfortDelGro',
#  "Trump's limited gag order reimposed in federal election subversion case",
#  'Delhi excise policy scam: SC rejects bail pleas of ex-Dy CM Manish Sisodia',
#  "Is your hotel sustainable? Not if these two things are in your room, says Soneva's founder",
#  'LG ENCOURAGES YOUTH WITH DISABILITIES TO PURSUE THEIR DREAMS AT 2023 GLOBAL IT CHALLENGE - PR Newswire',
#  'L&T Construction bags large orders for its Power Transmission & Distribution business',
#  'High-Performance Computing (HPC) Market to grow at a CAGR of 7.1% from 2022 to 2027, The market is driven by the ... - PR Newswire',
#  "Federal Judge Reinstates Trump's Gag Order In Election Interference Case"]
