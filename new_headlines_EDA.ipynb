# %%
import pandas as pd

df = pd.read_csv("news_data.csv")

# Display the first few rows to explore
# df.head()

new_df = df[['title', 'url', 'source', 'ticker_sentiment', 'overall_sentiment_score', 'overall_sentiment_label']]
new_df
# Out:
#                                                 title  \
# 0   Stocks to watch: RIL, Colgate-Palmolive, Axis ...
# 1   Former Premier Li Keqiang, China's top economi...
# 2   Russian journalist who protested war on live T...
# 3   GM's Cruise pauses driverless operations acros...
# 4   Chevron and Exxon's latest buys could usher in...
# 5   India's EAM to build $650-million EV battery m...
# 6   Amazon, Ford, Intel, Chipotle, Apple: Why Thes...
# 7   Enphase Energy  ( ENPH )  Q3 2023 Earnings Cal...
# 8   Amazon's profit margin nears record after CEO ...
# 9   Amazon's AI talk is making Wall Street drool, ...
# 10  Google CEO Sundar Pichai To Testify In Landmar...
# 11  Daily Voice | Niraj Kumar of Future Generali b...
# 12  Strategic Advisory Board Elevates sureti's Pro...
# 13  Japan's Matsuno expects BOJ to coordinate with...
# 14  KENVUE ALERT: Bragar Eagel & Squire, P.C. Remi...
# 15  'Buy Bitcoin' search queries on Google surge 8...
# ...
